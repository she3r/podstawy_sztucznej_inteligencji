# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# from help_plot import plot_decision_regions

# %% [markdown]
# # AdaBoost

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=500, noise=0.30, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

ada_clf = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=1), 
    n_estimators=1, learning_rate=0.5, 
    algorithm="SAMME.R", random_state=42)
ada_clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=0.5, n_estimators=1, random_state=42)

# %%
plot_decision_regions(X, y, ada_clf)
plt.show()

# %% [markdown]
# # Zad.
#
# Sprawdż różne parametry dla AdaBoostClassifier
#
# * n_estimators=2, learning_rate=0.5
# * n_estimators=2, learning_rate=1
# * n_estimators=10, learning_rate=0.5
# * n_estimators=10, learning_rate=1

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from mlxtend.plotting import plot_decision_regions
params = [(2, 0.5), (2, 1), (10, 0.5), (10, 1)]
for n, lr in params:
  print('(n_estirmators, learning_rate = (', n, ',', lr, ')')
  ada_clf = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=1),
    n_estimators= n, learning_rate= lr,
    algorithm="SAMME.R", random_state=42)
  ada_clf.fit(X_train, y_train)
  plot_decision_regions(X_test, y_test, ada_clf)
  plt.show()
# Out:
# (n_estirmators, learning_rate = ( 2 , 0.5 )
# (n_estirmators, learning_rate = ( 2 , 1 )
# (n_estirmators, learning_rate = ( 10 , 0.5 )
# (n_estirmators, learning_rate = ( 10 , 1 )
