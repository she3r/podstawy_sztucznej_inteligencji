# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# from help_plot import plot_decision_regions

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=500, noise=0.30, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %%
from sklearn.ensemble import GradientBoostingClassifier

ada_clf = GradientBoostingClassifier(n_estimators=1, learning_rate=0.5, random_state=42)
ada_clf.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.5, n_estimators=1, random_state=42)

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train, y_train, ada_clf)
plt.show()

# %% [markdown]
# # Zad.
#
# Sprawdż różne parametry dla GradientBoostingClassifier
#
# * n_estimators=2, learning_rate=0.5
# * n_estimators=2, learning_rate=1
# * n_estimators=10, learning_rate=0.5
# * n_estimators=10, learning_rate=1

# %%
ada_clf1 = GradientBoostingClassifier(n_estimators=2, learning_rate=0.5, random_state=42)
ada_clf2 = GradientBoostingClassifier(n_estimators=2, learning_rate=1, random_state=42)
ada_clf3 = GradientBoostingClassifier(n_estimators=10, learning_rate=0.5, random_state=42)
ada_clf4 = GradientBoostingClassifier(n_estimators=10, learning_rate=1, random_state=42)
ada_clf1.fit(X_train, y_train)
ada_clf2.fit(X_train, y_train)
ada_clf3.fit(X_train, y_train)
ada_clf4.fit(X_train, y_train)
plot_decision_regions(X_test, y_test, ada_clf1)
plt.show()
plot_decision_regions(X_test, y_test, ada_clf2)
plt.show()
plot_decision_regions(X_test, y_test, ada_clf3)
plt.show()
plot_decision_regions(X_test, y_test, ada_clf4)
plt.show()

# %% [markdown]
# # Zad.
#
# Sprawdż różne parametry dla XGBClassifier
#
# * n_estimators=2, learning_rate=0.5
# * n_estimators=2, learning_rate=1
# * n_estimators=10, learning_rate=0.5
# * n_estimators=10, learning_rate=1

# %%
try:
    import xgboost
except ImportError as ex:
    print("Error: the xgboost library is not installed.")
    xgboost = None

# %%
xgb_reg1 = xgboost.XGBClassifier(max_depth = 10, n_estimators=2,learning_rate=0.5, random_state=42)
xgb_reg2 = xgboost.XGBClassifier(max_depth = 10, n_estimators=2,learning_rate=1, random_state=42)
xgb_reg3 = xgboost.XGBClassifier(max_depth = 10, n_estimators=10,learning_rate=0.5, random_state=42)
xgb_reg4 = xgboost.XGBClassifier(max_depth = 10, n_estimators=10,learning_rate=1, random_state=42)
xgb_reg1.fit(X_train, y_train)
xgb_reg2.fit(X_train, y_train)
xgb_reg3.fit(X_train, y_train)
xgb_reg4.fit(X_train, y_train)
# y_pred = xgb_reg1.predict(X_test)
# print(y_pred)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='', learning_rate=1,
#               max_bin=256, max_cat_to_onehot=4, max_delta_step=0, max_depth=10,
#               max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=10, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=42,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(X_train, y_train, xgb_reg1);plt.show()
plot_decision_regions(X_train, y_train, xgb_reg2);plt.show()
plot_decision_regions(X_train, y_train, xgb_reg3);plt.show()
plot_decision_regions(X_train, y_train, xgb_reg4);plt.show()
