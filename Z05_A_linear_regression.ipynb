# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k')
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2,x**3) ).T
p3 = np.linalg.lstsq(M3, y, rcond=None)
f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1]*pow(x,1) + p3[0][0]

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack( (np.ones_like(x), x, x**2,x**3,x**4) ).T
p4 = np.linalg.lstsq(M4, y, rcond=None)
f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1]*pow(x,1) + p4[0][0]

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2,x**3,x**4,x**5) ).T
p5 = np.linalg.lstsq(M5, y, rcond=None)
f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2]*pow(x,2) + p5[0][1]*pow(x,1) + p5[0][0]

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najlepsza?

# %%
fig, axs = plt.subplots(1,5,figsize=(15,5))
y_f_lr5 = f_lr_5(x_tr)
y_f_lr4 = f_lr_4(x_tr)
y_f_lr3 = f_lr_3(x_tr)
y_f_lr2 = f_lr_2(x_tr)
y_f_lr1 = f_lr_1(x_tr)
for a in axs:
    a.plot(x, y, 'ok', ms=10)
axs[0].plot(x_tr,y_f_lr5,'b',label='deg = 5')
axs[1].plot(x_tr,y_f_lr4,'g',label='deg = 4')
axs[2].plot(x_tr,y_f_lr3,'r',label='deg = 3')
axs[3].plot(x_tr,y_f_lr2,'c',label='deg = 2')
axs[4].plot(x_tr,y_f_lr1,'m',label='deg = 1')
plt.tight_layout()
fig.legend(loc='upper center')
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.463
# Dependent Variable: y                AIC:                639.0748
# Date:               2022-04-12 23:05 BIC:                644.2852
# No. Observations:   100              Log-Likelihood:     -317.54
# Df Model:           1                F-statistic:        86.52
# Df Residuals:       98               Prob (F-statistic): 3.97e-15
# R-squared:          0.469            Scale:              34.229
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -3.3416     1.1843   -2.8215   0.0058   -5.6919   -0.9913
# x1         6.6729     0.7174    9.3015   0.0000    5.2493    8.0966
# -----------------------------------------------------------------
# Omnibus:              32.749       Durbin-Watson:          1.735
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       58.469
# Skew:                 1.369        Prob(JB):               0.000
# Kurtosis:             5.556        Condition No.:          4
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.778
# Dependent Variable: y                AIC:                551.6830
# Date:               2022-04-12 23:05 BIC:                559.4985
# No. Observations:   100              Log-Likelihood:     -272.84
# Df Model:           2                F-statistic:        174.7
# Df Residuals:       97               Prob (F-statistic): 6.96e-33
# R-squared:          0.783            Scale:              14.146
# ------------------------------------------------------------------
#             Coef.    Std.Err.     t     P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const        8.2699    1.2417   6.6602  0.0000    5.8054   10.7343
# x1         -14.7836    1.8703  -7.9045  0.0000  -18.4956  -11.0716
# x2           7.0400    0.5947  11.8379  0.0000    5.8597    8.2204
# -----------------------------------------------------------------
# Omnibus:              0.991        Durbin-Watson:           1.894
# Prob(Omnibus):        0.609        Jarque-Bera (JB):        1.047
# Skew:                 0.144        Prob(JB):                0.592
# Kurtosis:             2.590        Condition No.:           25
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.991
# Dependent Variable: y                AIC:                234.2006
# Date:               2022-04-12 23:05 BIC:                244.6212
# No. Observations:   100              Log-Likelihood:     -113.10
# Df Model:           3                F-statistic:        3563.
# Df Residuals:       96               Prob (F-statistic): 2.94e-98
# R-squared:          0.991            Scale:              0.58564
# ------------------------------------------------------------------
#            Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const      -4.1623    0.3642  -11.4297  0.0000   -4.8852   -3.4395
# x1         27.4869    0.9695   28.3502  0.0000   25.5624   29.4115
# x2        -26.5711    0.7193  -36.9395  0.0000  -27.9989  -25.1432
# x3          7.3011    0.1540   47.4022  0.0000    6.9954    7.6069
# -----------------------------------------------------------------
# Omnibus:              2.626        Durbin-Watson:           1.581
# Prob(Omnibus):        0.269        Jarque-Bera (JB):        2.639
# Skew:                 0.368        Prob(JB):                0.267
# Kurtosis:             2.698        Condition No.:           168
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -45.5316
# Date:               2022-04-12 23:05 BIC:                -32.5057
# No. Observations:   100              Log-Likelihood:     27.766
# Df Model:           4                F-statistic:        4.462e+04
# Df Residuals:       95               Prob (F-statistic): 1.47e-154
# R-squared:          0.999            Scale:              0.035370
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -1.0769     0.1199    -8.9812   0.0000   -1.3150   -0.8389
# x1        10.5005     0.4998    21.0080   0.0000    9.5082   11.4928
# x2        -2.5493     0.6460    -3.9461   0.0002   -3.8318   -1.2668
# x3        -4.8028     0.3154   -15.2290   0.0000   -5.4289   -4.1767
# x4         1.9787     0.0512    38.6592   0.0000    1.8771    2.0803
# ------------------------------------------------------------------
# Omnibus:              0.330         Durbin-Watson:           1.817
# Prob(Omnibus):        0.848         Jarque-Bera (JB):        0.501
# Skew:                 -0.048        Prob(JB):                0.778
# Kurtosis:             2.667         Condition No.:           1259
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -44.4365
# Date:               2022-04-12 23:05 BIC:                -28.8054
# No. Observations:   100              Log-Likelihood:     28.218
# Df Model:           5                F-statistic:        3.564e+04
# Df Residuals:       94               Prob (F-statistic): 2.16e-152
# R-squared:          0.999            Scale:              0.035424
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const      -1.1666     0.1543   -7.5619   0.0000   -1.4729   -0.8603
# x1         11.2259     0.9306   12.0635   0.0000    9.3782   13.0735
# x2         -4.1247     1.8228   -2.2629   0.0259   -7.7439   -0.5055
# x3         -3.4464     1.5009   -2.2962   0.0239   -6.4265   -0.4663
# x4          1.4787     0.5433    2.7216   0.0077    0.3999    2.5575
# x5          0.0659     0.0713    0.9244   0.3577   -0.0757    0.2075
# ------------------------------------------------------------------
# Omnibus:              0.244         Durbin-Watson:           1.789
# Prob(Omnibus):        0.885         Jarque-Bera (JB):        0.423
# Skew:                 -0.047        Prob(JB):                0.810
# Kurtosis:             2.696         Condition No.:           10113
# ==================================================================
# * The condition number is large (1e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.469
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     86.52
# Date:                Tue, 12 Apr 2022   Prob (F-statistic):           3.97e-15
# Time:                        23:05:24   Log-Likelihood:                -317.54
# No. Observations:                 100   AIC:                             639.1
# Df Residuals:                      98   BIC:                             644.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.3416      1.184     -2.822      0.006      -5.692      -0.991
# x              6.6729      0.717      9.302      0.000       5.249       8.097
# ==============================================================================
# Omnibus:                       32.749   Durbin-Watson:                   1.735
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               58.469
# Skew:                           1.369   Prob(JB):                     2.01e-13
# Kurtosis:                       5.556   Cond. No.                         4.34
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.778
# Method:                 Least Squares   F-statistic:                     174.7
# Date:                Tue, 12 Apr 2022   Prob (F-statistic):           6.96e-33
# Time:                        23:05:24   Log-Likelihood:                -272.84
# No. Observations:                 100   AIC:                             551.7
# Df Residuals:                      97   BIC:                             559.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.2699      1.242      6.660      0.000       5.805      10.734
# x            -14.7836      1.870     -7.904      0.000     -18.496     -11.072
# I(x ** 2)      7.0400      0.595     11.838      0.000       5.860       8.220
# ==============================================================================
# Omnibus:                        0.991   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.609   Jarque-Bera (JB):                1.047
# Skew:                           0.144   Prob(JB):                        0.592
# Kurtosis:                       2.590   Cond. No.                         24.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
