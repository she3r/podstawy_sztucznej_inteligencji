# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k')
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2,x**3) ).T
p3 = np.linalg.lstsq(M3, y, rcond=None)
f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1]*pow(x,1) + p3[0][0]

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack( (np.ones_like(x), x, x**2,x**3,x**4) ).T
p4 = np.linalg.lstsq(M4, y, rcond=None)
f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1]*pow(x,1) + p4[0][0]

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2,x**3,x**4,x**5) ).T
p5 = np.linalg.lstsq(M5, y, rcond=None)
f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2]*pow(x,2) + p5[0][1]*pow(x,1) + p5[0][0]

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najlepsza?

# %%
fig, axs = plt.subplots(1,5,figsize=(15,5))
y_f_lr5 = f_lr_5(x_tr)
y_f_lr4 = f_lr_4(x_tr)
y_f_lr3 = f_lr_3(x_tr)
y_f_lr2 = f_lr_2(x_tr)
y_f_lr1 = f_lr_1(x_tr)
for a in axs:
    a.plot(x, y, 'ok', ms=10)
axs[0].plot(x_tr,y_f_lr5,'b',label='deg = 5')
axs[1].plot(x_tr,y_f_lr4,'g',label='deg = 4')
axs[2].plot(x_tr,y_f_lr3,'r',label='deg = 3')
axs[3].plot(x_tr,y_f_lr2,'c',label='deg = 2')
axs[4].plot(x_tr,y_f_lr1,'m',label='deg = 1')
plt.tight_layout()
fig.legend(loc='upper center')
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.499
# Dependent Variable: y                AIC:                659.7361
# Date:               2022-03-26 15:34 BIC:                664.9464
# No. Observations:   100              Log-Likelihood:     -327.87
# Df Model:           1                F-statistic:        99.54
# Df Residuals:       98               Prob (F-statistic): 1.36e-16
# R-squared:          0.504            Scale:              42.085
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -5.9896     1.5142   -3.9555   0.0001   -8.9945   -2.9846
# x1         8.0236     0.8042    9.9768   0.0000    6.4277    9.6196
# -----------------------------------------------------------------
# Omnibus:              13.067       Durbin-Watson:          1.909
# Prob(Omnibus):        0.001        Jarque-Bera (JB):       14.172
# Skew:                 0.902        Prob(JB):               0.001
# Kurtosis:             3.381        Condition No.:          5
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.839
# Dependent Variable: y                AIC:                547.3857
# Date:               2022-03-26 15:34 BIC:                555.2012
# No. Observations:   100              Log-Likelihood:     -270.69
# Df Model:           2                F-statistic:        258.2
# Df Residuals:       97               Prob (F-statistic): 1.41e-39
# R-squared:          0.842            Scale:              13.551
# ------------------------------------------------------------------
#             Coef.    Std.Err.     t     P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const        9.3641    1.3693   6.8384  0.0000    6.6464   12.0819
# x1         -17.9097    1.8578  -9.6401  0.0000  -21.5970  -14.2224
# x2           8.1145    0.5635  14.4000  0.0000    6.9961    9.2329
# -----------------------------------------------------------------
# Omnibus:               10.527       Durbin-Watson:          1.716
# Prob(Omnibus):         0.005        Jarque-Bera (JB):       4.164
# Skew:                  0.198        Prob(JB):               0.125
# Kurtosis:              2.082        Condition No.:          31
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.994
# Dependent Variable: y                AIC:                222.2883
# Date:               2022-03-26 15:34 BIC:                232.7090
# No. Observations:   100              Log-Likelihood:     -107.14
# Df Model:           3                F-statistic:        5298.
# Df Residuals:       96               Prob (F-statistic): 1.81e-106
# R-squared:          0.994            Scale:              0.51987
# -------------------------------------------------------------------
#             Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# -------------------------------------------------------------------
# const       -4.5872    0.3898  -11.7676  0.0000   -5.3610   -3.8135
# x1          29.2821    1.0237   28.6034  0.0000   27.2500   31.3142
# x2         -27.9183    0.7389  -37.7836  0.0000  -29.3850  -26.4516
# x3           7.5706    0.1535   49.3189  0.0000    7.2659    7.8753
# ------------------------------------------------------------------
# Omnibus:               1.762        Durbin-Watson:           1.802
# Prob(Omnibus):         0.414        Jarque-Bera (JB):        1.751
# Skew:                  0.309        Prob(JB):                0.417
# Kurtosis:              2.807        Condition No.:           223
# ==================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -22.2798
# Date:               2022-03-26 15:34 BIC:                -9.2540
# No. Observations:   100              Log-Likelihood:     16.140
# Df Model:           4                F-statistic:        4.655e+04
# Df Residuals:       95               Prob (F-statistic): 1.97e-155
# R-squared:          0.999            Scale:              0.044629
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -0.7468     0.1657    -4.5070   0.0000   -1.0758   -0.4179
# x1         9.0605     0.6997    12.9492   0.0000    7.6714   10.4496
# x2        -0.9667     0.8699    -1.1113   0.2692   -2.6937    0.7602
# x3        -5.4449     0.4094   -13.3013   0.0000   -6.2576   -4.6323
# x4         2.0663     0.0646    31.9889   0.0000    1.9381    2.1945
# ------------------------------------------------------------------
# Omnibus:               1.262        Durbin-Watson:           1.873
# Prob(Omnibus):         0.532        Jarque-Bera (JB):        1.125
# Skew:                  0.075        Prob(JB):                0.570
# Kurtosis:              2.502        Condition No.:           1836
# ==================================================================
# * The condition number is large (2e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -20.3322
# Date:               2022-03-26 15:34 BIC:                -4.7012
# No. Observations:   100              Log-Likelihood:     16.166
# Df Model:           5                F-statistic:        3.686e+04
# Df Residuals:       94               Prob (F-statistic): 4.43e-153
# R-squared:          0.999            Scale:              0.045080
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const      -0.7827     0.2319   -3.3744   0.0011   -1.2432   -0.3221
# x1          9.3152     1.3455    6.9231   0.0000    6.6437   11.9868
# x2         -1.4745     2.4480   -0.6023   0.5484   -6.3350    3.3860
# x3         -5.0330     1.9000   -2.6490   0.0095   -8.8055   -1.2606
# x4          1.9207     0.6589    2.9150   0.0044    0.6124    3.2290
# x5          0.0186     0.0839    0.2221   0.8247   -0.1480    0.1852
# ------------------------------------------------------------------
# Omnibus:               1.228        Durbin-Watson:           1.872
# Prob(Omnibus):         0.541        Jarque-Bera (JB):        1.123
# Skew:                  0.090        Prob(JB):                0.570
# Kurtosis:              2.513        Condition No.:           14324
# ==================================================================
# * The condition number is large (1e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.499
# Method:                 Least Squares   F-statistic:                     99.54
# Date:                Sat, 26 Mar 2022   Prob (F-statistic):           1.36e-16
# Time:                        15:35:48   Log-Likelihood:                -327.87
# No. Observations:                 100   AIC:                             659.7
# Df Residuals:                      98   BIC:                             664.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.9896      1.514     -3.956      0.000      -8.995      -2.985
# x              8.0236      0.804      9.977      0.000       6.428       9.620
# ==============================================================================
# Omnibus:                       13.067   Durbin-Watson:                   1.909
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.172
# Skew:                           0.902   Prob(JB):                     0.000837
# Kurtosis:                       3.381   Cond. No.                         5.45
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.842
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     258.2
# Date:                Sat, 26 Mar 2022   Prob (F-statistic):           1.41e-39
# Time:                        15:35:48   Log-Likelihood:                -270.69
# No. Observations:                 100   AIC:                             547.4
# Df Residuals:                      97   BIC:                             555.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.3641      1.369      6.838      0.000       6.646      12.082
# x            -17.9097      1.858     -9.640      0.000     -21.597     -14.222
# I(x ** 2)      8.1145      0.564     14.400      0.000       6.996       9.233
# ==============================================================================
# Omnibus:                       10.527   Durbin-Watson:                   1.716
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):                4.164
# Skew:                           0.198   Prob(JB):                        0.125
# Kurtosis:                       2.082   Cond. No.                         30.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
