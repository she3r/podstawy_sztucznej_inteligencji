# %% [markdown]
# # Regresja liniowa i wielomianowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k')
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
x=np.vstack(x)
model1 = linear_model.LinearRegression()
model1.fit(x, y)
# Out:
# LinearRegression()

# %%
print(model1.coef_)
print(model1.intercept_)
print(model1.score(x,y))
# Out:
# [7.07992466]
# -3.9952626407635616
# 0.5122218624848676

# %%
# Plot outputs
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
plt.plot(x, model1.predict(x), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
model2 = make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression())
model2.fit(x, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
# Plot outputs
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model2.predict(x_plot), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
model3 = make_pipeline(PolynomialFeatures(3), linear_model.LinearRegression())
model3.fit(x,y)

# Plot outputs
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model3.predict(x_plot), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
model4 = make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression())
model4.fit(x,y)

# Plot outputs
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model4.predict(x_plot), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
model5 = make_pipeline(PolynomialFeatures(5), linear_model.LinearRegression())
model5.fit(x,y)

# Plot outputs
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model5.predict(x_plot), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_plot, model1.predict(x_plot), 'r')
plt.plot(x_plot, model2.predict(x_plot), 'g')
plt.plot(x_plot, model3.predict(x_plot), 'b')
plt.plot(x_plot, model4.predict(x_plot), 'c')
plt.plot(x_plot, model5.predict(x_plot), 'g')
plt.plot(x, y, 'ok', ms=10)
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
from sklearn import  metrics

def gradeModel(model : linear_model.LinearRegression):
    error1 = np.average( np.abs(model.predict(x) -y) )
    print("Mean absolute errors: {}".format(error1))
    print("Mean absolute errors: {}".format(metrics.mean_absolute_error(y, model.predict(x))))

    error2 = np.average( (model.predict(x) -y) **2 )
    print("Mean squared error: {}".format(error2))
    print("Mean squared error: {}".format( metrics.mean_squared_error(y, model.predict(x)) ))

    error3 = np.median( np.abs(model.predict(x) -y) )
    print("Median absolute error: {}".format( error3 ))
    print("Median absolute error: {}".format( metrics.median_absolute_error(y, model.predict(x)) ))

    print("R^2: {}".format(metrics.r2_score(y, model.predict(x))))
    ss_res=np.sum( (y-model.predict(x))**2 )
    ss_tot=np.sum( (y-np.mean(y))**2 )
    R=1-ss_res/ss_tot
    print("R^2: {}".format(R))

    error4 = 1-np.var(y - model.predict(x) )/np.var(y)
    print("Explained variance score: {}".format( error4 ))
    print("Explained variance score: {}".format( metrics.explained_variance_score(y, model.predict(x)) ))

# %% [markdown]
# # Zadanie
#
# Wylicz powyższe miary dla wszytkich modeli.

# %%
toGrade = [model1,model2,model3,model4,model5]
for i in range(len(toGrade)):
    print(f"{i+1} model")
    gradeModel(toGrade[i])
    print()
# Out:
# 1 'th model
# Mean absolute errors: 4.602350192486909
# Mean absolute errors: 4.602350192486909
# Mean squared error: 33.57316993120114
# Mean squared error: 33.57316993120114
# Median absolute error: 3.715671431691847
# Median absolute error: 3.715671431691847
# R^2: 0.5122218624848676
# R^2: 0.5122218624848676
# Explained variance score: 0.5122218624848676
# Explained variance score: 0.5122218624848676
#
# 2 'th model
# Mean absolute errors: 2.773532441547356
# Mean absolute errors: 2.773532441547356
# Mean squared error: 12.05802812596843
# Mean squared error: 12.05802812596843
# Median absolute error: 2.5910048555357577
# Median absolute error: 2.5910048555357577
# R^2: 0.8248112253492075
# R^2: 0.8248112253492075
# Explained variance score: 0.8248112253492075
# Explained variance score: 0.8248112253492075
#
# 3 'th model
# Mean absolute errors: 0.6513332233243168
# Mean absolute errors: 0.6513332233243168
# Mean squared error: 0.6070283175134207
# Mean squared error: 0.6070283175134207
# Median absolute error: 0.6278950613174099
# Median absolute error: 0.6278950613174099
# R^2: 0.9911806021670755
# R^2: 0.9911806021670755
# Explained variance score: 0.9911806021670755
# Explained variance score: 0.9911806021670755
#
# 4 'th model
# Mean absolute errors: 0.15609703260171778
# Mean absolute errors: 0.15609703260171778
# Mean squared error: 0.03858397837591852
# Mean squared error: 0.03858397837591852
# Median absolute error: 0.13279406072182076
# Median absolute error: 0.13279406072182076
# R^2: 0.99943942078902
# R^2: 0.99943942078902
# Explained variance score: 0.99943942078902
# Explained variance score: 0.99943942078902
#
# 5 'th model
# Mean absolute errors: 0.15551773443847072
# Mean absolute errors: 0.15551773443847072
# Mean squared error: 0.03855015289936504
# Mean squared error: 0.03855015289936504
# Median absolute error: 0.12968777425017142
# Median absolute error: 0.12968777425017142
# R^2: 0.999439912232872
# R^2: 0.999439912232872
# Explained variance score: 0.999439912232872
# Explained variance score: 0.999439912232872
